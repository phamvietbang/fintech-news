# %%
# !pip install pyspark
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
SPARK_RPC_AUTHENTICATION_SECRET="c5e203148272d39fb5227e3279bc1f96a5154b650c1be4297effa3c271ce3d7c"
SPARK_SSL_KEY_PASSWORD="293036HaNoi@"
SPARK_SSL_KEYSTORE_PASSWORD="293036HaNoi@"
SPARK_SSL_TRUSTSTORE_PASSWORD="293036HaNoi@"
SPARK_SSL_KEYSTORE_FILE="./keystore.jks"
SPARK_SSL_TRUSTSTORE_FILE="./truststore.jks"

# %%
from pyspark.sql import SparkSession

# Create a SparkSession
spark = SparkSession.builder \
    .appName("Spark Connection Check") \
    .master("spark://172.21.0.2:7077") \
    .config("spark.authenticate", "true") \
    .config("spark.authenticate.secret", SPARK_RPC_AUTHENTICATION_SECRET) \
    .getOrCreate()

# Print SparkSession details
print("SparkSession created successfully")
print("Spark Master URL:", spark.sparkContext.master)

# Stop the SparkSession
spark.stop()
# Out:
# 24/08/19 13:52:57 WARN Utils: Your hostname, bang resolves to a loopback address: 127.0.1.1; using 172.168.15.60 instead (on interface wlp0s20f3)
# 24/08/19 13:52:57 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/08/19 13:52:57 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# SparkSession created successfully
# Spark Master URL: spark://172.21.0.2:7077
